# %% [markdown]
# The first thing we will be doing is importing our csv necessary files before the merge. The csv below depicts earning potential and level of employment by county.

# %%
import pandas as pd

#importing csv files
employment = pd.read_csv('../../../../data/stage_1/employment.csv')
covid19 = pd.read_csv('../../../team/stage_1/merged_covid19.csv')

# %%
employment
# Out:
#       Area\nCode   St  Cnty  Own  NAICS  Year Qtr Area Type St Name  \
# 0          US000   US   0.0    0     10  2020   A    Nation     NaN
# 1          US000   US   0.0    1     10  2020   A    Nation     NaN
# 2          US000   US   0.0    2     10  2020   A    Nation     NaN
# 3          US000   US   0.0    3     10  2020   A    Nation     NaN
# 4          US000   US   0.0    5     10  2020   A    Nation     NaN
# ...          ...  ...   ...  ...    ...   ...  ..       ...     ...
# 62887      C4974  NaN   NaN    5   1024  2020   A       MSA     NaN
# 62888      C4974  NaN   NaN    5   1025  2020   A       MSA     NaN
# 62889      C4974  NaN   NaN    5   1026  2020   A       MSA     NaN
# 62890      C4974  NaN   NaN    5   1027  2020   A       MSA     NaN
# 62891      C4974  NaN   NaN    5   1029  2020   A       MSA     NaN
#
#                Area           Ownership  \
# 0        U.S. TOTAL       Total Covered
# 1        U.S. TOTAL  Federal Government
# ...

# %% [markdown]
# After displaying the intial notebook we now need to merge the enrichment dataset with the covid dataset created by our team. The easiest way to do this would be to align the state abbreviations and county names so that they match between the two data sets and then finally merging the two.

# %%
#merging the covid 19 and employment dataset
merged = pd.merge(covid19, employment, left_index=True, right_index=True)
display(merged.head())
# Out:
#          countyFIPS_cases State_cases  StateFIPS_cases  2020-01-22_cases  \
# UID
# 01001AL              1001          AL                1                 0
# 01003AL              1003          AL                1                 0
# 01005AL              1005          AL                1                 0
# 01007AL              1007          AL                1                 0
# 01009AL              1009          AL                1                 0
#
#          2020-01-24_cases  2020-01-26_cases  2020-01-27_cases  \
# UID
# 01001AL                 0                 0                 0
# 01003AL                 0                 0                 0
# 01005AL                 0                 0                 0
# 01007AL                 0                 0                 0
# 01009AL                 0                 0                 0
#
#          2020-01-29_cases  2020-01-31_cases  2020-02-01_cases  ...  \
# UID                                                            ...
# ...

# %% [markdown]
# And finally, for the last section we will be calculating COVID-19 data trends for the last week of the data. The state that was chosen for this analysis was North Carolina. The simplest approach to this would be using iloc to centrally locate the final week of data that was recorded. A graph will also be displayed to aid with visual representation and then a conclusion can finally be made on whether cases are rising or declining.

# %%
#reading in necessary csv for analysis
cases = pd.read_csv("../../../../data/stage_1/covid_confirmed_usafacts.csv")
finalweek = cases.iloc[1923:2023, 548:555]
# Out:
#       2021-08-10  2021-08-11  2021-08-12  2021-08-13  2021-08-14  2021-08-15  \
# 1923          11          11          11         108         108         108
# 1924       19945       20012       20079       20202       20202       20202
# 1925        4741        4764        4794        4812        4812        4812
# 1926        1132        1132        1134        1138        1138        1138
# 1927        2789        2794        2802        2815        2815        2815
#
#       2021-08-16                 county
# 1923          11  Statewide Unallocated
# 1924       20380       Alamance County
# 1925        4869      Alexander County
# 1926        1143      Alleghany County
# 1927        2847          Anson County

# %% [markdown]
# Analysis:
# Looking at the data, it is pretty evident that cases were rising throughout the final week that data was recorded in North Carolina. This could partly be due to the fact that many children were returning to school during the week of 08/10/2021-08/16/2021. Another potential reason could be because this was during the middle of the summer delta variant surge. All counties seem to have a steady rise and that trend can be seen more clearly in more populated counties.
